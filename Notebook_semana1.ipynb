# %% [markdown]
# <a href="https://colab.research.google.com/github/jopima87-design/Notebooks-Agro_2026_1/blob/main/Notebook_semana1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ancho = 1
alto = 2

lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho + alto)

print(lm)
print(av)
# Out:
# 19.5
# 6
